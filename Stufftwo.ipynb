# %%
lenlist = []
aax = int(input('how many words? '))
for i in range(aax):
    x = input('enter a word: ')
    ax = len(x)
    lenlist.append(ax)
print(lenlist)
# Out:
# [4, 6, 8, 2]

# %%
lenlisttwo = []
aay = int(input('how many words? '))
for i in range(aay):
    y = input('enter a word: ')
    ay = len(y)
    if ay > 3:
        lenlisttwo.append(y)
print(lenlisttwo)
# Out:
# ['moon', 'charred']

# %%
lenlistthree = []
aaz = int(input('how many words? '))
for i in range(aaz):
    z = input('enter a word: ')
    az = z [::-1]
    lenlistthree.append(az)
print(lenlistthree)
# Out:
# ['tac', 'god']

# %%
lst = []
def count_even_odd(lst):
    even = 0
    odd = 0
    for item in lst:
        if item %2 == 0:
            even += 1
        else:
            odd += 1
    finaldict = {'even':even, 'odd':odd}
    print(finaldict)
adarav = int(input('how many numbers? '))
for i in range(adarav):
    odorev = int(input('enter a number: '))
    lst.append(odorev)
count_even_odd(lst)
# Out:
# {'even': 1, 'odd': 2}

# %%
mix = [1, '4', 'a', 3.14159, 90, 'end']
summ = 0

for item in mix:
    if type(item) == int or type(item) == float:
        summ = item + summ
    else:
        summ + 0
print(summ)
# Out:
# 94.14159

# %%
try:
    div1 = int(input('Enter a number'))
    div2 = int(input('Enter a number'))
    
    print(div1 / div2)
except ZeroDivisionError:
    print('Do not enter 0')
except ValueError:
    print('Enter a number')
# Out:
# Do not enter 0

# %%
blist = [1, 2, 3, 4, 6, -2, 0, 1]
y = blist[1]
for it in blist:
    if it > y:
        y = it
print(y)
# Out:
# 6

# %%
hwlist = [1, 2, 3, -5]
x = 0
for items in hwlist:
    if items > 0:
        x += 1
print('there are', x, 'numbers greater than 0')
# Out:
# there are 3 numbers greater than 0

# %%
lista = [1, 2, 3]
listb = [2, 3, 4]
listc = []
for thing in lista:
    if thing in listb:
        listc.append(thing)
print(listc)
# Out:
# [2, 3]
