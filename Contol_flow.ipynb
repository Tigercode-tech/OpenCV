# %%
int2 = 4
if type(int2) == int:
    print("true")
else:
    print("false")
# Out:
# true

# %%
type(3+4)
# Out:
# int

# %%
i=3
while i>1:
    print(i)
    i-=1
    if i==1:
        break
else:
    print('bad output')
# Out:
# 3
# 2

# %%
evenlist = [] 
oddlist = []
for i in range(10):
    lisrt = int(input('Enter a sequence of numbers'))
    if lisrt == 0:
        break
    if lisrt %2 == 0:
        evenlist.append(lisrt)
    else:
        oddlist.append(lisrt)
e = len(evenlist)
o = len(oddlist)
print(e, o)
# Out:
# 5 5

# %%
for var in input('Enter a word'):
    if var not in('a', 'e', 'i', 'o', 'u'):
        print(var, end='')
# Out:
# wrd

# %%
i = int(input("Type a number"))
if i % 2 == 0:
    print('That is an even number')
else:
    print('That is an odd number')
# Out:
# That is an odd number

# %%
print("he said: \"let's learn python!\"")
# Out:
# he said: "let's learn python!"

# %%
age = input("What is your age?")
if age >21:
    print("You are not a minor")
else: 
    print('You are a minor')

# %%
age = 12
ega = "you are not a minor" if age >=21 else "You are a minor"
print(ega)
# Out:
# You are a minor

# %%
itn = 6
if int == type(itn):
    print('true')
else:
    print('False')
# Out:
# true

# %%
x = int(input('enter age'))
if x<= 12:
    y = int(input('enter flight distance'))
    if y >= 1000:
        print('$400')
    else:
        print('$200')
if x >12 and x <65:
    y = int(input('enter flight distance'))
    if y >= 1000:
        print('$500')
    else:
        print('$400')
if x >=65:
    y = int(input('enter flight distance'))
    if y >= 1000:
        print('$450')
    else:
        print('$350')
# Out:
# $350

# %%
p = int(input('Give me a number'))
if p%2 == 0:
    print('that is an even number')
    if p < 0:
        print('that is a negative number')
    else:
        print('that is a positive number')
else:
    print('that is an odd number')
    if p < 0:
        print('that is a negative number')
    else:
        print('that is a positive number')
# Out:
# that is an odd number
# that is a positive number

# %%
int1 = 10
int2 = 6
if(int1 != int2):
    int2 =+ int2
print(int1 - int2)
# Out:
# 4
