# %%
def function1():
    return(True)
function1()
# Out:
# True

# %%
def function2(argument = 'Red'):
    if argument == 'Red':
        print('Okay')
    if argument  == 'Green':
            print('OK')
function2()
# Out:
# Okay

# %%
def function3(a,b,c):
    return c,b,a
function3(1,2,3)
# Out:
# (3, 2, 1)

# %%
function3(c=7, a=9, b=86750)
# Out:
# (7, 86750, 9)

# %%
function3(90, b=87, c=4)
# Out:
# (4, 87, 90)

# %%
six = 6
def chang():
    global six
    six = 8
chang()
print(six)
# Out:
# 8

# %%
def function4(u):
    u = 'Assigned'
var = 18
function4(var)
print(var)
# Out:
# 18

# %%
def function4(u):
    u[0] = 19
var = [18]
function4(var)
print(var)
# Out:
# [19]
